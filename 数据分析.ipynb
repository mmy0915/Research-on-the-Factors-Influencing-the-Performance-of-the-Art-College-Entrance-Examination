# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

# Common imports
import numpy as np
import os

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

import pandas as pd

# %%
file1 = "/Users/ichigo34/Downloads/2.招生数据分析项目/回归分析/报名信息汇总.xls"
df_baoming = pd.read_excel(file1)

# %%
file2 = "/Users/ichigo34/Downloads/2.招生数据分析项目/回归分析/合格汇总信息.xls"
df_hege = pd.read_excel(file2)

# %%
file3 = "/Users/ichigo34/Downloads/2.招生数据分析项目/回归分析/录取汇总信息.xls"
df_luqu = pd.read_excel(file3)

# %%
df_baoming.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113682 entries, 0 to 113681
# Data columns (total 25 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   招生年度    113682 non-null  int64
#  1   层次      113682 non-null  object
#  2   报名类型    113682 non-null  object
#  3   性别      113682 non-null  object
#  4   院系      113682 non-null  object
#  5   专业      113682 non-null  object
#  6   专业方向    113682 non-null  object
#  7   考点      113507 non-null  object
#  8   准考证号    109214 non-null  float64
#  9   是否往报    113682 non-null  object
#  10  出生日期    113679 non-null  object
#  11  政治面貌名称  113676 non-null  object
#  12  民族名称    113681 non-null  object
#  13  考生类别名称  113681 non-null  object
#  14  考生性质名称  113678 non-null  object
#  15  高考类别    113681 non-null  float64
#  16  高考类别名称  113681 non-null  object
#  17  文化程度名称  113677 non-null  object
#  18  身高      113679 non-null  float64
#  19  毕业中学名称  113681 non-null  object
# ...

# %%
df_baoming.head()
# Out:
#    招生年度  层次  报名类型 性别    院系        专业            专业方向  考点          准考证号 是否往报  \
# 0  2016  本科  全国统招  女  美术学院  戏剧影视美术设计  戏剧影视美术设计（特技设计）  北京  1.611011e+13    是
# 1  2016  本科  全国统招  女  美术学院  戏剧影视美术设计   戏剧影视美术设计（新媒体）  北京  1.611011e+13    是
# 2  2016  本科  全国统招  男  动画学院        动画              动画  北京  1.611011e+13    是
# 3  2016  本科  全国统招  男  动画学院    戏剧影视文学    戏剧影视文学（动漫策划）  北京  1.611011e+13    是
# 4  2016  本科  全国统招  男  管理学院       电影学      电影学（制片与市场）  北京  1.611011e+13    是
#
#    ... 高考类别 高考类别名称 文化程度名称     身高 毕业中学名称           高考报名号 高考所在省 户口所在地  高考所在市  \
# 0  ...  1.0     文科     高中  155.0   工美附中  16110101111605   北京市   北京市    市辖区
# 1  ...  1.0     文科     高中  155.0   工美附中  16110101111605   北京市   北京市    市辖区
# 2  ...  2.0     理科     高中  175.0   哈市八中  16230102270018  黑龙江省  黑龙江省   哈尔滨市
# 3  ...  1.0     文科     高中  177.0   颍上一中  16341226130081   安徽省   安徽省    阜阳市
# 4  ...  1.0     文科     高中  177.0   颍上一中  16341226130081   安徽省   安徽省    阜阳市
#
#   高考所在县
# 0   东城区
# 1   东城区
# 2   道里区
# 3   颍上县
# 4   颍上县
# ...
